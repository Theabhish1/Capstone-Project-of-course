# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# # **Step 1- Loading the chat data into python environment**

# %%
chat_file = 'WhatsApp Chat with B.Tech CSE 4th  Year.txt'    # This Project is done using Google Colab

# Read the text file
with open(chat_file, 'r', encoding='utf-8') as file:
    chat_data = file.readlines()

# Join all lines into a single string
chat_text = ' '.join(chat_data)

print("WhatsApp Chat Data loaded successfully!")
# Out:
# WhatsApp Chat Data loaded successfully!

# %% [markdown]
# # **Step 2- Defining the specific function or methods for preprocessing the text data**

# %%
import nltk
nltk.download('punkt')

import nltk
nltk.download('stopwords')


def clean_text(text):
    # Remove unnecessary metadata (timestamps, etc.)
    text = re.sub(r'\d{1,2}/\d{1,2}/\d{2,4}, \d{1,2}:\d{2} [APM]{2} - ', '', text)

    # Remove special characters
    text = re.sub(r'[^\w\s]', '', text)

    # Convert to lowercase
    text = text.lower()

    return text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # **Step 3- Incorporating NLP techniques for cleaning the text data**

# %%
# Clean the chat text
cleaned_text = clean_text(chat_text)

# Tokenization
tokens = word_tokenize(cleaned_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

# Initialize stemming
porter = PorterStemmer()
stemmed_tokens = [porter.stem(word) for word in filtered_tokens]

# Join tokens back into a single string
processed_text = ' '.join(stemmed_tokens)

print("Text Data Preprocessing completed!")
# Out:
# Text Data Preprocessing completed!

# %% [markdown]
# # **Step 4- Creating Word Clouds of the processed chat data**

# %%
# Generate WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(processed_text)

# Display the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WhatsApp Chat Word Cloud')
plt.show()

# %% [markdown]
# # **Step 5- Save the images of word cloud in your system**

# %%
 #Specify the path where you want to save
save_path = r'C:\Users\Abhishek Jaiswal\OneDrive\Documents\wordcloud.png'  # Change this path to your desired location

try:
# Save WordCloud as image
  wordcloud.to_file(save_path)

  print(f"Word Cloud saved as image: {save_path}")
except Exception as e:
    print(f"Error saving Word Cloud: {str(e)}")
# Out:
# Word Cloud saved as image: C:\Users\Abhishek Jaiswal\OneDrive\Documents\wordcloud.png

# %% [markdown]
# # **Step 6- Extracting information through sentiment analysis**

# %%
from textblob import TextBlob

# Function to perform sentiment analysis using TextBlob
def sentiment_analysis(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Perform sentiment analysis on processed_text
sentiment_score = sentiment_analysis(processed_text)

if sentiment_score > 0:
    sentiment_label = "Positive"
elif sentiment_score < 0:
    sentiment_label = "Negative"
else:
    sentiment_label = "Neutral"
    print("neutral")

print(f"Sentiment Analysis Result: {sentiment_label} (Score: {sentiment_score})")
# Out:
# Sentiment Analysis Result: Positive (Score: 0.08729306047487859)

# %%
sentiment_analysis("intzar") #Positive Word
# Out:
# 0.0

# %%
sentiment_analysis("student") #Positive Word
# Out:
# 0.0

# %%
sentiment_analysis("bad") #Negative Word
# Out:
# -0.6999999999999998

# %%
sentiment_analysis("angry") #Negative Word
# Out:
# -0.5

# %%
sentiment_analysis("Awesome")  #Positive Word
# Out:
# 1.0
